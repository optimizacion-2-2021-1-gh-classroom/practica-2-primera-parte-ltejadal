# %% [markdown]
# # Reporte Práctica 2, Parte 1
# ***

# %%
# importamos
#from ant_colony.aco_tsp import *
import tsplib95
import networkx as nx
from ant_colony.utils import *

from ant_colony import aco_tsp_oo

# %%
#Cargamos el dataset
data_path2 = 'datasets/gr17.tsp'

# %%
# lectura de datos en formato tsp
problem = tsplib95.load(data_path2)
# convertir a grafo 
G = problem.get_graph()
# matrix numerica para diccionario de distancias
G_num = nx.to_numpy_matrix(G)
# diccionario de distancias
dic_dists = create_dic_dist_from_graph(G)

# inicializacion de atraccion y feromonas
tau = init_ferom(G)
eta = init_atrac(G,dic_dists)
A = atraccion_nodos(G, tau, eta, alpha=1, beta=5)

# %% [markdown]
# Antes de esto el reporte debe de ser con el reporte que habíamos hecho la vez pasada.

# %% [markdown]
# Para la parte de la base de china poner que la RAM se satura y no es problema del código, sino de la capacidad de la instancia. Mejor probaremos con otra base.

# %% [markdown]
# ## Implementación del nuevo código
# Este se usará para validación del nuevo código

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,
                 best_route = [],
                 best_dist = float('inf'),
                 n_ants=2,
                 max_iter=100, 
                 alpha=1, 
                 beta=5, 
                 rho=.5, 
                 verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# Cambiamos los parámetros y ponemos los de la vez pasada:

# %% [markdown]
# #### Configuración 1

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=200, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 2

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=100, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 3

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=1000, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 4

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=5000, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 5

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=1, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 6

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=5, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 7

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=3,max_iter=1, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# ### Variando el Número de Hormigas

# %% [markdown]
# #### Configuración 8

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=1,max_iter=500, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 9

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=5,max_iter=500, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 10

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=10,max_iter=500, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 11

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=15,max_iter=500, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# #### Configuración 12

# %%
respuesta = aco_tsp_oo.colony( G, init_node=1,best_route = [],best_dist = float('inf'),n_ants=50,max_iter=500, alpha=1, beta=5, rho=.5, verbose=1)

# %%
respuesta.solve_tsp()

# %%
respuesta.plot_route()

# %% [markdown]
# Hay que comparar a ver si se mejoró respecto a la vez pasada.

# %% [markdown]
# Si no se puede cargar con la base de Argentina entonces hay que hacer modificaciones.

# %% [markdown]
# ### Lo de aquí abajo es lo del reporte anterior:

# %%
plot_graph(G, m_plot='graph')

# %%
route, dist = hormiga_recorre(G,dic_dists, A, tau, 0, x_best=[], y_best= float('inf'))
graph_optim_path(G, route, dist)

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=3, max_iter=500, verbose=20)
# Out:
# iter: 1 / 500 - dist: 4671.0
# iter: 20 / 500 - dist: 4671.0
# iter: 40 / 500 - dist: 4671.0
# iter: 60 / 500 - dist: 4671.0
# iter: 80 / 500 - dist: 4671.0
# iter: 100 / 500 - dist: 4671.0
# iter: 120 / 500 - dist: 4671.0
# iter: 140 / 500 - dist: 4671.0
# iter: 160 / 500 - dist: 4671.0
# iter: 180 / 500 - dist: 4671.0
# iter: 200 / 500 - dist: 4671.0
# iter: 220 / 500 - dist: 4671.0
# iter: 240 / 500 - dist: 4671.0
# iter: 260 / 500 - dist: 4671.0
# iter: 280 / 500 - dist: 4671.0
# iter: 300 / 500 - dist: 4671.0
# iter: 320 / 500 - dist: 4671.0
# iter: 340 / 500 - dist: 4671.0
# iter: 360 / 500 - dist: 4671.0
# iter: 380 / 500 - dist: 4671.0
# iter: 400 / 500 - dist: 4671.0
# iter: 420 / 500 - dist: 4671.0
# iter: 440 / 500 - dist: 4671.0
# iter: 460 / 500 - dist: 4671.0
# iter: 480 / 500 - dist: 4671.0
# iter: 500 / 500 - dist: 4671.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 3
# 	Iteraciones: 500
# 	Distancia: 4671.0
# 	Nodo inicial: 0
# 	Ruta: [0, 1, 2, 6, 7, 15, 3, 5, 9, 14, 4, 11, 10, 16, 13, 8, 12, 0]
# ------------------------------

# %% [markdown]
# ## Cambiamos los parámetros para ver que el modelo siga ejecutándose correctamente

# %% [markdown]
# Si cambiamos el parámetro de épocas notamos que realmente no hay cambios, ya que el algoritmo llega al óptimo en las primeras iteraciones:

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=3, max_iter=200, verbose=20)
# Out:
# iter: 1 / 200 - dist: 4692.0
# iter: 20 / 200 - dist: 4692.0
# iter: 40 / 200 - dist: 4692.0
# iter: 60 / 200 - dist: 4692.0
# iter: 80 / 200 - dist: 4692.0
# iter: 100 / 200 - dist: 4692.0
# iter: 120 / 200 - dist: 4692.0
# iter: 140 / 200 - dist: 4692.0
# iter: 160 / 200 - dist: 4692.0
# iter: 180 / 200 - dist: 4692.0
# iter: 200 / 200 - dist: 4692.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 3
# 	Iteraciones: 200
# 	Distancia: 4692.0
# 	Nodo inicial: 0
# 	Ruta: [0, 13, 9, 16, 12, 11, 5, 6, 7, 15, 2, 14, 10, 8, 1, 4, 3, 0]
# ------------------------------

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=3, max_iter=100, verbose=20)
# Out:
# iter: 1 / 100 - dist: 4692.0
# iter: 20 / 100 - dist: 4692.0
# iter: 40 / 100 - dist: 4692.0
# iter: 60 / 100 - dist: 4692.0
# iter: 80 / 100 - dist: 4692.0
# iter: 100 / 100 - dist: 4692.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 3
# 	Iteraciones: 100
# 	Distancia: 4692.0
# 	Nodo inicial: 0
# 	Ruta: [0, 13, 9, 16, 12, 11, 5, 6, 7, 15, 2, 14, 10, 8, 1, 4, 3, 0]
# ------------------------------

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=3, max_iter=1000, verbose=20)
# Out:
# iter: 1 / 1000 - dist: 4692.0
# iter: 20 / 1000 - dist: 4692.0
# iter: 40 / 1000 - dist: 4692.0
# iter: 60 / 1000 - dist: 4692.0
# iter: 80 / 1000 - dist: 4692.0
# iter: 100 / 1000 - dist: 4692.0
# iter: 120 / 1000 - dist: 4692.0
# iter: 140 / 1000 - dist: 4692.0
# iter: 160 / 1000 - dist: 4692.0
# iter: 180 / 1000 - dist: 4692.0
# iter: 200 / 1000 - dist: 4692.0
# iter: 220 / 1000 - dist: 4692.0
# iter: 240 / 1000 - dist: 4692.0
# iter: 260 / 1000 - dist: 4692.0
# iter: 280 / 1000 - dist: 4692.0
# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=5, max_iter=500, verbose=20)
# Out:
# iter: 1 / 500 - dist: 4692.0
# iter: 20 / 500 - dist: 4692.0
# iter: 40 / 500 - dist: 4692.0
# iter: 60 / 500 - dist: 4692.0
# iter: 80 / 500 - dist: 4692.0
# iter: 100 / 500 - dist: 4692.0
# iter: 120 / 500 - dist: 4692.0
# iter: 140 / 500 - dist: 4692.0
# iter: 160 / 500 - dist: 4692.0
# iter: 180 / 500 - dist: 4692.0
# iter: 200 / 500 - dist: 4692.0
# iter: 220 / 500 - dist: 4692.0
# iter: 240 / 500 - dist: 4692.0
# iter: 260 / 500 - dist: 4692.0
# iter: 280 / 500 - dist: 4692.0
# iter: 300 / 500 - dist: 4692.0
# iter: 320 / 500 - dist: 4692.0
# iter: 340 / 500 - dist: 4692.0
# iter: 360 / 500 - dist: 4692.0
# iter: 380 / 500 - dist: 4692.0
# iter: 400 / 500 - dist: 4692.0
# iter: 420 / 500 - dist: 4692.0
# iter: 440 / 500 - dist: 4692.0
# iter: 460 / 500 - dist: 4692.0
# iter: 480 / 500 - dist: 4692.0
# iter: 500 / 500 - dist: 4692.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 5
# 	Iteraciones: 500
# 	Distancia: 4692.0
# 	Nodo inicial: 0
# 	Ruta: [0, 13, 9, 16, 12, 11, 5, 6, 7, 15, 2, 14, 10, 8, 1, 4, 3, 0]
# ------------------------------

# %% [markdown]
# Cuando aumentamos el número de hormigas y fijamos el número de ietaciones en `500` el algoritmo alcanza un nivel más bajo en la distancia desde las primeras iteraciones:

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=10, max_iter=500, verbose=20)
# Out:
# iter: 1 / 500 - dist: 4681.0
# iter: 20 / 500 - dist: 4681.0
# iter: 40 / 500 - dist: 4681.0
# iter: 60 / 500 - dist: 4681.0
# iter: 80 / 500 - dist: 4681.0
# iter: 100 / 500 - dist: 4681.0
# iter: 120 / 500 - dist: 4681.0
# iter: 140 / 500 - dist: 4681.0
# iter: 160 / 500 - dist: 4681.0
# iter: 180 / 500 - dist: 4681.0
# iter: 200 / 500 - dist: 4681.0
# iter: 220 / 500 - dist: 4681.0
# iter: 240 / 500 - dist: 4681.0
# iter: 260 / 500 - dist: 4681.0
# iter: 280 / 500 - dist: 4681.0
# iter: 300 / 500 - dist: 4681.0
# iter: 320 / 500 - dist: 4681.0
# iter: 340 / 500 - dist: 4681.0
# iter: 360 / 500 - dist: 4681.0
# iter: 380 / 500 - dist: 4681.0
# iter: 400 / 500 - dist: 4681.0
# iter: 420 / 500 - dist: 4681.0
# iter: 440 / 500 - dist: 4681.0
# iter: 460 / 500 - dist: 4681.0
# iter: 480 / 500 - dist: 4681.0
# iter: 500 / 500 - dist: 4681.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 10
# 	Iteraciones: 500
# 	Distancia: 4681.0
# 	Nodo inicial: 0
# 	Ruta: [0, 13, 8, 5, 9, 4, 12, 16, 3, 11, 14, 1, 15, 10, 2, 7, 6, 0]
# ------------------------------

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=15, max_iter=500, verbose=20)
# Out:
# iter: 1 / 500 - dist: 4681.0
# iter: 20 / 500 - dist: 4681.0
# iter: 40 / 500 - dist: 4681.0
# iter: 60 / 500 - dist: 4681.0
# iter: 80 / 500 - dist: 4681.0
# iter: 100 / 500 - dist: 4681.0
# iter: 120 / 500 - dist: 4681.0
# iter: 140 / 500 - dist: 4681.0
# iter: 160 / 500 - dist: 4681.0
# iter: 180 / 500 - dist: 4681.0
# iter: 200 / 500 - dist: 4681.0
# iter: 220 / 500 - dist: 4681.0
# iter: 240 / 500 - dist: 4681.0
# iter: 260 / 500 - dist: 4681.0
# iter: 280 / 500 - dist: 4681.0
# iter: 300 / 500 - dist: 4681.0
# iter: 320 / 500 - dist: 4681.0
# iter: 340 / 500 - dist: 4681.0
# iter: 360 / 500 - dist: 4681.0
# iter: 380 / 500 - dist: 4681.0
# iter: 400 / 500 - dist: 4681.0
# iter: 420 / 500 - dist: 4681.0
# iter: 440 / 500 - dist: 4681.0
# iter: 460 / 500 - dist: 4681.0
# iter: 480 / 500 - dist: 4681.0
# iter: 500 / 500 - dist: 4681.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 15
# 	Iteraciones: 500
# 	Distancia: 4681.0
# 	Nodo inicial: 0
# 	Ruta: [0, 13, 8, 5, 9, 4, 12, 16, 3, 11, 14, 1, 15, 10, 2, 7, 6, 0]
# ------------------------------

# %%
# antcolony
ruta, dist = ant_colony(G, dic_dists, init=0, ants=50, max_iter=500, verbose=20)
# Out:
# iter: 1 / 500 - dist: 4681.0
# iter: 20 / 500 - dist: 4681.0
# iter: 40 / 500 - dist: 4681.0
# iter: 60 / 500 - dist: 4681.0
# iter: 80 / 500 - dist: 4681.0
# iter: 100 / 500 - dist: 4681.0
# iter: 120 / 500 - dist: 4681.0
# iter: 140 / 500 - dist: 4681.0
# iter: 160 / 500 - dist: 4681.0
# iter: 180 / 500 - dist: 4681.0
# iter: 200 / 500 - dist: 4681.0
# iter: 220 / 500 - dist: 4681.0
# iter: 240 / 500 - dist: 4681.0
# iter: 260 / 500 - dist: 4681.0
# iter: 280 / 500 - dist: 4681.0
# iter: 300 / 500 - dist: 4681.0
# iter: 320 / 500 - dist: 4681.0
# iter: 340 / 500 - dist: 4681.0
# iter: 360 / 500 - dist: 4681.0
# iter: 380 / 500 - dist: 4681.0
# iter: 400 / 500 - dist: 4681.0
# iter: 420 / 500 - dist: 4681.0
# iter: 440 / 500 - dist: 4681.0
# iter: 460 / 500 - dist: 4681.0
# iter: 480 / 500 - dist: 4681.0
# iter: 500 / 500 - dist: 4681.0
#
#
# ------------------------------
# Resumen:
# 	Nro. de hormigas: 50
# 	Iteraciones: 500
# 	Distancia: 4681.0
# 	Nodo inicial: 0
# 	Ruta: [0, 13, 8, 5, 9, 4, 12, 16, 3, 11, 14, 1, 15, 10, 2, 7, 6, 0]
# ------------------------------

# %% [markdown]
# Si utilizamos una cantidad mucho mayor de hormigas el algoritmo se vuelve considerablemente lento, y ya no disminuye la distancia:
